# %%
# 라이브러리 호출
import cv2
import os
from google.colab import drive

drive.mount('/content/drive')

print(cv2.__version__)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 4.12.0

# %% [markdown]
# video -> frame

# %%
base_dir = '/content/drive/MyDrive/Colab Notebooks/data/train_videos (1)/'

output_root = os.path.join(base_dir, "video_to_frame")
os.makedirs(output_root, exist_ok=True)

for file in os.listdir(base_dir):
    if not file.endswith(".mp4"):
        continue

    video_path = os.path.join(base_dir, file)
    video_name = os.path.splitext(file)[0]

    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)

    if fps <= 0:
        print(f"[SKIP] {file}: FPS 정보 X")
        continue

    interval = max(1, round(fps/5))

    frame_idx = 0
    saved = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        if frame_idx%interval == 0:
            cv2.imwrite(
                os.path.join(output_root, f"{video_name}_{saved:04d}.png"), frame
            )

            saved += 1

        frame_idx += 1

    cap.release()
    print(f"[DONE] {file} -> {saved} frames")
# Out:
# [DONE] abarnvbtwb.mp4 -> 50 frames
# [DONE] aagfhgtpmv.mp4 -> 50 frames
# [DONE] aapnvogymq.mp4 -> 50 frames
# [DONE] abofeumbvv.mp4 -> 50 frames
# [DONE] aevrfsexku.mp4 -> 50 frames
# [DONE] aelzhcnwgf.mp4 -> 50 frames
# [DONE] acxwigylke.mp4 -> 50 frames
# [DONE] acqfdwsrhi.mp4 -> 50 frames
# [DONE] adylbeequz.mp4 -> 50 frames
# [DONE] adhsbajydo.mp4 -> 50 frames
# [DONE] agqphdxmwt.mp4 -> 50 frames
# [DONE] aelfnikyqj.mp4 -> 50 frames
# [DONE] acifjvzvpm.mp4 -> 50 frames
# [DONE] aettqgevhz.mp4 -> 50 frames
# [DONE] abqwwspghj.mp4 -> 50 frames
# [DONE] acxnxvbsxk.mp4 -> 50 frames
# [DONE] agrmhtjdlk.mp4 -> 50 frames
# [DONE] ahbweevwpv.mp4 -> 50 frames
# [DONE] aczrgyricp.mp4 -> 50 frames
# [DONE] agdkmztvby.mp4 -> 50 frames
# [DONE] afoovlsmtx.mp4 -> 50 frames
# [DONE] adohikbdaz.mp4 -> 50 frames
# [DONE] altziddtxi.mp4 -> 50 frames
# [DONE] amowujxmzc.mp4 -> 50 frames
# [DONE] alaijyygdv.mp4 -> 50 frames
# [DONE] aladcziidp.mp4 -> 50 frames
# [DONE] andaxzscny.mp4 -> 50 frames
# [DONE] aknmpoonls.mp4 -> 50 frames
# [DONE] akxoopqjqz.mp4 -> 50 frames
# [DONE] ahqqqilsxt.mp4 -> 50 frames
# [DONE] alvgwypubw.mp4 -> 50 frames
# [DONE] ajqslcypsw.mp4 -> 50 frames
# [DONE] akzbnazxtz.mp4 -> 50 frames
# [DONE] aknbdpmgua.mp4 -> 50 frames
# [DONE] amaivqofda.mp4 -> 50 frames
# [DONE] ahdbuwqxit.mp4 -> 50 frames
# [DONE] akvmwkdyuv.mp4 -> 50 frames
# [DONE] alninxcyhg.mp4 -> 50 frames
# [DONE] aklqzsddfl.mp4 -> 50 frames
# [DONE] aipfdnwpoo.mp4 -> 50 frames
# [DONE] ajwpjhrbcv.mp4 -> 50 frames
# [DONE] ahfazfbntc.mp4 -> 50 frames
# [DONE] atvmxvwyns.mp4 -> 50 frames
# [DONE] asmpfjfzif.mp4 -> 50 frames
# [DONE] asaxgevnnp.mp4 -> 50 frames
# [DONE] arrhsnjqku.mp4 -> 50 frames
# [DONE] apgjqzkoma.mp4 -> 50 frames
# [DONE] asdpeebotb.mp4 -> 50 frames
# [DONE] apogckdfrz.mp4 -> 50 frames
# [DONE] atkdltyyen.mp4 -> 50 frames
# [DONE] aslsvlvpth.mp4 -> 50 frames
# [DONE] apatcsqejh.mp4 -> 50 frames
# [DONE] aneclqfpbt.mp4 -> 50 frames
# [DONE] asvcrfdpnq.mp4 -> 50 frames
# [DONE] arlmiizoob.mp4 -> 50 frames
# [DONE] aorjvbyxhw.mp4 -> 50 frames
# [DONE] anpuvshzoo.mp4 -> 50 frames
# [DONE] aqpnvjhuzw.mp4 -> 50 frames
# [DONE] arkroixhey.mp4 -> 50 frames
# [DONE] avfitoutyn.mp4 -> 50 frames
# [DONE] avibnnhwhp.mp4 -> 50 frames
# [DONE] atyntldecu.mp4 -> 50 frames
# [DONE] augtsuxpzc.mp4 -> 50 frames
# [DONE] avgiuextiz.mp4 -> 50 frames
# [DONE] atzdznmder.mp4 -> 50 frames
# [DONE] aufmsmnoye.mp4 -> 50 frames
# [DONE] atxvxouljq.mp4 -> 50 frames
# [DONE] awnwkrqibf.mp4 -> 50 frames
# [DONE] avvdgsennp.mp4 -> 50 frames
# [DONE] avnqydkqjj.mp4 -> 50 frames
# [DONE] avmjormvsx.mp4 -> 50 frames
# [DONE] axczxisdtb.mp4 -> 50 frames
# [DONE] awhmfnnjih.mp4 -> 50 frames
# [DONE] awukslzjra.mp4 -> 50 frames
# [DONE] avssvvsdhz.mp4 -> 50 frames
# [DONE] avywawptfc.mp4 -> 50 frames
# [DONE] avtycwsgyb.mp4 -> 50 frames
# [DONE] axwgcsyphv.mp4 -> 50 frames
# [DONE] aytzyidmgs.mp4 -> 50 frames
# [DONE] azsmewqghg.mp4 -> 50 frames
# [DONE] axwovszumc.mp4 -> 50 frames
# [DONE] aybumesmpk.mp4 -> 50 frames
# [DONE] axoygtekut.mp4 -> 50 frames
# [DONE] azpuxunqyo.mp4 -> 50 frames
# [DONE] axntxmycwd.mp4 -> 50 frames
# [DONE] ayqvfdhslr.mp4 -> 50 frames
# [DONE] aybgughjxh.mp4 -> 50 frames
# [DONE] bbhtdfuqxq.mp4 -> 50 frames
# [DONE] bbvgxeczei.mp4 -> 50 frames
# [DONE] bdgipnyobr.mp4 -> 50 frames
# [DONE] bdxuhamuqx.mp4 -> 50 frames
# [DONE] bddjdhzfze.mp4 -> 50 frames
# [DONE] bctvsmddgq.mp4 -> 50 frames
# [DONE] bdnaqemxmr.mp4 -> 50 frames
# [DONE] bdbhekrrwo.mp4 -> 50 frames
# [DONE] bchnbulevv.mp4 -> 50 frames
# [DONE] beboztfcme.mp4 -> 50 frames
# [DONE] bbhpvrmbse.mp4 -> 50 frames
# [DONE] bahdpoesir.mp4 -> 50 frames
# [DONE] bguwlyazau.mp4 -> 50 frames
# [DONE] bejhvclboh.mp4 -> 50 frames
# [DONE] bghphrsfxf.mp4 -> 50 frames
# [DONE] bhpwpydzpo.mp4 -> 50 frames
# [DONE] bggsurpgpr.mp4 -> 50 frames
# [DONE] bhsluedavd.mp4 -> 50 frames
# [DONE] beyebyhrph.mp4 -> 50 frames
# [DONE] benmsfzfaz.mp4 -> 50 frames
# [DONE] bhaaboftbc.mp4 -> 50 frames
# [DONE] bffwsjxghk.mp4 -> 50 frames
# [DONE] bgwmmujlmc.mp4 -> 50 frames
# [DONE] bjjbwsqjir.mp4 -> 50 frames
# [DONE] bgmlwsoamc.mp4 -> 50 frames
# [DONE] bgaogsjehq.mp4 -> 50 frames
# [DONE] bgvhtpzknn.mp4 -> 50 frames
# [DONE] bilnggbxgu.mp4 -> 50 frames
# [DONE] bhbdugnurr.mp4 -> 50 frames
# [DONE] bnjcdrfuov.mp4 -> 50 frames
# [DONE] bkmdzhfzfh.mp4 -> 50 frames
# [DONE] bpwzipqtxf.mp4 -> 50 frames
# [DONE] bofqajtwve.mp4 -> 50 frames
# [DONE] bntlodcfeg.mp4 -> 50 frames
# [DONE] blzydqdfem.mp4 -> 50 frames
# [DONE] bmbbkwmxqj.mp4 -> 50 frames
# [DONE] bjkmjilrxp.mp4 -> 50 frames
# [DONE] bmioepcpsx.mp4 -> 50 frames
# [DONE] blpchvmhxx.mp4 -> 50 frames
# [DONE] bmhvktyiwp.mp4 -> 50 frames
# [DONE] bkvetcojbt.mp4 -> 50 frames
# [DONE] bndybcqhfr.mp4 -> 50 frames
# [DONE] bkwxhglwct.mp4 -> 50 frames
# [DONE] bmjzrlszhi.mp4 -> 50 frames
# [DONE] bpxckdzddv.mp4 -> 50 frames
# [DONE] bpapbctoao.mp4 -> 50 frames
# [DONE] bnbuonyoje.mp4 -> 50 frames
# [DONE] bjsmaqefoi.mp4 -> 50 frames
# [DONE] bopqhhalml.mp4 -> 50 frames
# [DONE] bourlmzsio.mp4 -> 50 frames
# [DONE] boovltmuwi.mp4 -> 50 frames
# [DONE] bmehkyanbj.mp4 -> 50 frames
# [DONE] bmjmjmbglm.mp4 -> 50 frames
# [DONE] bqqpbzjgup.mp4 -> 50 frames
# [DONE] bqeiblbxtl.mp4 -> 50 frames
# [DONE] bqnymlsayl.mp4 -> 50 frames
# [DONE] btjlfpzbdu.mp4 -> 50 frames
# [DONE] bulkxhhknf.mp4 -> 50 frames
# [DONE] bqkdbcqjvb.mp4 -> 50 frames
# [DONE] brhalypwoo.mp4 -> 50 frames
# [DONE] bsqgziaylx.mp4 -> 50 frames
# [DONE] bqtuuwzdtr.mp4 -> 50 frames
# [DONE] bqhtpqmmqp.mp4 -> 50 frames
# [DONE] btjwbtsgln.mp4 -> 50 frames
# [DONE] bqdjzqhcft.mp4 -> 50 frames
# [DONE] brvqtabyxj.mp4 -> 50 frames
# [DONE] btugrnoton.mp4 -> 50 frames
# [DONE] btxlttbpkj.mp4 -> 50 frames
# [DONE] brwrlczjvi.mp4 -> 50 frames
# [DONE] bseamdrpbj.mp4 -> 50 frames
# [DONE] btohlidmru.mp4 -> 50 frames
# [DONE] btunxncpjh.mp4 -> 50 frames
# [DONE] btiysiskpf.mp4 -> 50 frames
# [DONE] bsfmwclnqy.mp4 -> 50 frames
# [DONE] btmsngnqhv.mp4 -> 50 frames
# [DONE] caqbrkogkb.mp4 -> 50 frames
# [DONE] caifxvsozs.mp4 -> 50 frames
# [DONE] bzythlfnhq.mp4 -> 50 frames
# [DONE] byqzyxifza.mp4 -> 50 frames
# [DONE] byijojkdba.mp4 -> 50 frames
# [DONE] byofowlkki.mp4 -> 50 frames
# [DONE] cdaxixbosp.mp4 -> 50 frames
# [DONE] byunigvnay.mp4 -> 50 frames
# [DONE] bwipwzzxxu.mp4 -> 50 frames
# [DONE] ccmonzqfrz.mp4 -> 50 frames
# [DONE] bvzjkezkms.mp4 -> 50 frames
# [DONE] bydaidkpdp.mp4 -> 50 frames
# [DONE] byyqectxqa.mp4 -> 50 frames
# [DONE] cbbibzcoih.mp4 -> 50 frames
# [DONE] bweezhfpzp.mp4 -> 50 frames
# [DONE] bxzakyopjf.mp4 -> 50 frames
# [DONE] byfenovjnf.mp4 -> 50 frames
# [DONE] bwuwstvsbw.mp4 -> 50 frames
# [DONE] ccfoszqabv.mp4 -> 50 frames
# [DONE] bvgwelbeof.mp4 -> 50 frames
# [DONE] cbltdtxglo.mp4 -> 50 frames
# [DONE] cdbsbdymzd.mp4 -> 50 frames
# [DONE] bwhlgysghg.mp4 -> 50 frames
# [DONE] bzmdrafeex.mp4 -> 50 frames
# [DONE] clihsshdkq.mp4 -> 50 frames
# [DONE] cglxirfaey.mp4 -> 50 frames
# [DONE] ckbdwedgmc.mp4 -> 50 frames
# [DONE] ckjaibzfxa.mp4 -> 50 frames
# [DONE] ckkuyewywx.mp4 -> 50 frames
# [DONE] chtapglbcj.mp4 -> 50 frames
# [DONE] cdphtzqrvp.mp4 -> 50 frames
# [DONE] ceymbecxnj.mp4 -> 50 frames
# [DONE] cffffbcywc.mp4 -> 50 frames
# [DONE] cdyakrxkia.mp4 -> 50 frames
# [DONE] cfxkpiweqt.mp4 -> 50 frames
# [DONE] cettndmvzl.mp4 -> 50 frames
# [DONE] chviwxsfhg.mp4 -> 50 frames
# [DONE] cknyxaqouy.mp4 -> 50 frames
# [DONE] cizlkenljw.mp4 -> 50 frames
# [DONE] cepxysienc.mp4 -> 50 frames
# [DONE] cfyduhpbps.mp4 -> 50 frames
# [DONE] ciyoudyhly.mp4 -> 50 frames
# [DONE] cksanfsjhc.mp4 -> 50 frames
# [DONE] cferslmfwh.mp4 -> 50 frames
# [DONE] cgvrgibpfo.mp4 -> 50 frames
# [DONE] chzieimrwu.mp4 -> 50 frames
# [DONE] crezycjqyk.mp4 -> 50 frames
# [DONE] cqfugiqupm.mp4 -> 50 frames
# [DONE] cnilkgvfei.mp4 -> 50 frames
# [DONE] cqhngvpgyi.mp4 -> 50 frames
# [DONE] cmbzllswnl.mp4 -> 50 frames
# [DONE] cqrskwiqng.mp4 -> 50 frames
# [DONE] clrycekyst.mp4 -> 50 frames
# [DONE] cppdvdejkc.mp4 -> 50 frames
# [DONE] cobjrlugvp.mp4 -> 50 frames
# [DONE] covdcysmbi.mp4 -> 50 frames
# [DONE] cmxcfkrjiv.mp4 -> 50 frames
# [DONE] coadfnerlk.mp4 -> 50 frames
# [DONE] cpjxareypw.mp4 -> 50 frames
# [DONE] crzfebnfgb.mp4 -> 50 frames
# [DONE] cprhtltsjp.mp4 -> 50 frames
# [DONE] crktehraph.mp4 -> 50 frames
# [DONE] ctpqeykqdp.mp4 -> 50 frames
# [DONE] cvaksbpssm.mp4 -> 50 frames
# [DONE] cwsbspfzck.mp4 -> 50 frames
# [DONE] cwrtyzndpx.mp4 -> 50 frames
# [DONE] curpwogllm.mp4 -> 50 frames
# [DONE] cxfujlvsuw.mp4 -> 50 frames
# [DONE] cxrfacemmq.mp4 -> 50 frames
# [DONE] cwwandrkus.mp4 -> 50 frames
# [DONE] cttqtsjvgn.mp4 -> 50 frames
# [DONE] cuzrgrbvil.mp4 -> 50 frames
# [DONE] cwqlvzefpg.mp4 -> 50 frames
# [DONE] cthdnahrkh.mp4 -> 50 frames
# [DONE] cwbacdwrzo.mp4 -> 50 frames
# [DONE] ctzmavwror.mp4 -> 50 frames
# [DONE] czmqpxrqoh.mp4 -> 50 frames
# [DONE] czfunozvwp.mp4 -> 50 frames
# [DONE] czkdanyadc.mp4 -> 50 frames
# [DONE] dbtbbhakdv.mp4 -> 50 frames
# [DONE] dbhoxkblzx.mp4 -> 50 frames
# [DONE] dcuiiorugd.mp4 -> 50 frames
# [DONE] dakqwktlbi.mp4 -> 50 frames
# [DONE] dcamvmuors.mp4 -> 50 frames
# [DONE] cxttmymlbn.mp4 -> 50 frames
# [DONE] cyclgfjdrv.mp4 -> 50 frames
# [DONE] dbzpcjntve.mp4 -> 50 frames
# [DONE] dakiztgtnw.mp4 -> 50 frames
# [DONE] cyxlcuyznd.mp4 -> 50 frames
# [DONE] dbhrpizyeq.mp4 -> 50 frames
# [DONE] dboxtiehng.mp4 -> 50 frames
# [DONE] dbnygxtwek.mp4 -> 50 frames
# [DONE] dafhtipaml.mp4 -> 50 frames
# [DONE] cycacemkmt.mp4 -> 50 frames
# [DONE] cyboodqqyr.mp4 -> 50 frames
# [DONE] dbzcqmxzaj.mp4 -> 50 frames
# [DONE] dgzklxjmix.mp4 -> 50 frames
# [DONE] dhcndnuwta.mp4 -> 50 frames
# [DONE] ddepeddixj.mp4 -> 50 frames
# [DONE] dhcselezer.mp4 -> 50 frames
# [DONE] dgxrqjdomn.mp4 -> 50 frames
# [DONE] deyyistcrd.mp4 -> 50 frames
# [DONE] dhxctgyoqj.mp4 -> 50 frames
# [DONE] degpbqvcay.mp4 -> 50 frames
# [DONE] deywhkarol.mp4 -> 50 frames
# [DONE] ddhfabwpuz.mp4 -> 50 frames
# [DONE] ddjggcasdw.mp4 -> 50 frames
# [DONE] dgmevclvzy.mp4 -> 50 frames
# [DONE] dhjmzhrcav.mp4 -> 50 frames
# [DONE] dhevettufk.mp4 -> 50 frames
# [DONE] diuzrpqjli.mp4 -> 50 frames
# [DONE] ddqccgmtka.mp4 -> 50 frames
# [DONE] dfbpceeaox.mp4 -> 50 frames
# [DONE] diomeixhrg.mp4 -> 50 frames
# [DONE] diopzaywor.mp4 -> 50 frames
# [DONE] dhkwmjxwrn.mp4 -> 50 frames
# [DONE] diqraixiov.mp4 -> 50 frames
# [DONE] ddpvuimigj.mp4 -> 50 frames
# [DONE] dhoqofwoxa.mp4 -> 50 frames
# [DONE] dqnyszdong.mp4 -> 50 frames
# [DONE] djvutyvaio.mp4 -> 50 frames
# [DONE] dntkzzzcdh.mp4 -> 50 frames
# [DONE] dlpoieqvfb.mp4 -> 50 frames
# [DONE] dozyddhild.mp4 -> 50 frames
# [DONE] dkzvdrzcnr.mp4 -> 50 frames
# [DONE] dofusvhnib.mp4 -> 50 frames
# [DONE] dptrzdvwpg.mp4 -> 50 frames
# [DONE] dnexlwbcxq.mp4 -> 50 frames
# [DONE] djvtbgwdcc.mp4 -> 50 frames
# [DONE] dkwjwbwgey.mp4 -> 50 frames
# [DONE] doanjploai.mp4 -> 50 frames
# [DONE] dkhlttuvmx.mp4 -> 50 frames
# [DONE] dlrsbscitn.mp4 -> 50 frames
# [DONE] dqqtjcryjv.mp4 -> 50 frames
# [DONE] dptbnjnkdg.mp4 -> 50 frames
# [DONE] dqppxmoqdl.mp4 -> 50 frames
# [DONE] dnyvfblxpm.mp4 -> 50 frames
# [DONE] dkrvorliqc.mp4 -> 50 frames
# [DONE] dkdwxmtpuo.mp4 -> 50 frames
# [DONE] dnhvalzvrt.mp4 -> 50 frames
# [DONE] djxdyjopjd.mp4 -> 50 frames
# [DONE] dkuayagnmc.mp4 -> 50 frames
# [DONE] dzieklokdr.mp4 -> 50 frames
# [DONE] drcyabprvt.mp4 -> 50 frames
# [DONE] drtbksnpol.mp4 -> 50 frames
# [DONE] dzqwgqewhu.mp4 -> 50 frames
# [DONE] dxuplhwvig.mp4 -> 50 frames
# [DONE] drgjzlxzxj.mp4 -> 50 frames
# [DONE] dvakowbgbt.mp4 -> 50 frames
# [DONE] dwediigjit.mp4 -> 50 frames
# [DONE] dqswpjoepo.mp4 -> 50 frames
# [DONE] dtbpmdqvao.mp4 -> 50 frames
# [DONE] dsndhujjjb.mp4 -> 50 frames
# [DONE] dvumqqhoac.mp4 -> 50 frames
# [DONE] dulanfulol.mp4 -> 50 frames
# [DONE] dxuliowugt.mp4 -> 50 frames
# [DONE] duvyaxbzvp.mp4 -> 50 frames
# [DONE] dqzreruvje.mp4 -> 50 frames
# [DONE] dtocdfbwca.mp4 -> 50 frames
# [DONE] dsdoseflas.mp4 -> 50 frames
# [DONE] duzuusuajr.mp4 -> 50 frames
# [DONE] dxbqjxrhin.mp4 -> 50 frames
# [DONE] dubiroskqn.mp4 -> 50 frames
# [DONE] duycddgtrl.mp4 -> 50 frames
# [DONE] drsakwyvqv.mp4 -> 50 frames
# [DONE] dsgpbgsrdm.mp4 -> 50 frames
# [DONE] dsjbknkujw.mp4 -> 50 frames
# [DONE] ebywfrmhtd.mp4 -> 50 frames
# [DONE] eckvhdusax.mp4 -> 50 frames
# [DONE] dzyuwjkjui.mp4 -> 50 frames
# [DONE] ebchwmwayp.mp4 -> 50 frames
# [DONE] eekozbeafq.mp4 -> 50 frames
# [DONE] eebserckhh.mp4 -> 50 frames
# [DONE] eebrkicpry.mp4 -> 50 frames
# [DONE] eczrseixwq.mp4 -> 50 frames
# [DONE] ecujsjhscd.mp4 -> 50 frames
# [DONE] edyncaijwx.mp4 -> 50 frames
# [DONE] ebeknhudxq.mp4 -> 50 frames
# [DONE] eeyhxisdfh.mp4 -> 50 frames
# [DONE] ecuvtoltue.mp4 -> 50 frames
# [DONE] dzvyfiarrq.mp4 -> 50 frames
# [DONE] ebebgmtlcu.mp4 -> 50 frames
# [DONE] eahlqmfvtj.mp4 -> 50 frames
# [DONE] efwfxwwlbw.mp4 -> 50 frames
# [DONE] efdyrflcpg.mp4 -> 50 frames
# [DONE] eajlrktemq.mp4 -> 50 frames
# [DONE] eejswgycjc.mp4 -> 50 frames
# [DONE] ebkzwjgjhq.mp4 -> 50 frames
# [DONE] ecwaxgutkc.mp4 -> 50 frames
# [DONE] ecnihjlfyt.mp4 -> 50 frames
# [DONE] eepezmygaq.mp4 -> 50 frames
# [DONE] dzwkmcwkwl.mp4 -> 50 frames
# [DONE] ellavthztb.mp4 -> 50 frames
# [DONE] ehfiekigla.mp4 -> 50 frames
# [DONE] ehieahnhte.mp4 -> 50 frames
# [DONE] ekhacizpah.mp4 -> 50 frames
# [DONE] ejkqesyvam.mp4 -> 50 frames
# [DONE] eivxffliio.mp4 -> 50 frames
# [DONE] elginszwtk.mp4 -> 50 frames
# [DONE] ehdkmxgtxh.mp4 -> 50 frames
# [DONE] elvvackpjh.mp4 -> 50 frames
# [DONE] egghxjjmfg.mp4 -> 50 frames
# [DONE] emaalmsonj.mp4 -> 50 frames
# [DONE] eiwopxzjfn.mp4 -> 50 frames
# [DONE] ekcrtigpab.mp4 -> 50 frames
# [DONE] ehccixxzoe.mp4 -> 50 frames
# [DONE] ehevsxtecd.mp4 -> 50 frames
# [DONE] eiriyukqqy.mp4 -> 50 frames
# [DONE] eixwxvxbbn.mp4 -> 50 frames
# [DONE] eggbjzxnmg.mp4 -> 50 frames
# [DONE] ekkdjkirzq.mp4 -> 50 frames
# [DONE] ehtdtkmmli.mp4 -> 50 frames
# [DONE] egbbcxcuqy.mp4 -> 50 frames
# [DONE] ehbnclaukr.mp4 -> 50 frames
# [DONE] esgftaficx.mp4 -> 50 frames
# [DONE] esckbnkkvb.mp4 -> 50 frames
# [DONE] eqvuznuwsa.mp4 -> 50 frames
# [DONE] eqnoqyfquo.mp4 -> 50 frames
# [DONE] ensyyivobf.mp4 -> 50 frames
# [DONE] eoewqcpbgt.mp4 -> 50 frames
# [DONE] epymyyiblu.mp4 -> 50 frames
# [DONE] eprybmbpba.mp4 -> 50 frames
# [DONE] erlvuvjsjf.mp4 -> 50 frames
# [DONE] esyhwdfnxs.mp4 -> 50 frames
# [DONE] esnntzzajv.mp4 -> 50 frames
# [DONE] erqgqacbqe.mp4 -> 50 frames
# [DONE] eqjscdagiv.mp4 -> 50 frames
# [DONE] emfbhytfhc.mp4 -> 50 frames
# [DONE] errocgcham.mp4 -> 50 frames
# [DONE] esxrvsgpvb.mp4 -> 50 frames
# [DONE] emgjphonqb.mp4 -> 50 frames
# [DONE] eudeqjhdfd.mp4 -> 50 frames
# [DONE] etejaapnxh.mp4 -> 50 frames
# [DONE] etdcqxabww.mp4 -> 50 frames
# [DONE] esyrimvzsa.mp4 -> 50 frames
# [DONE] etmcruaihe.mp4 -> 50 frames
# [DONE] eukvucdetx.mp4 -> 50 frames
# [DONE] etohcvnzbj.mp4 -> 50 frames

# %% [markdown]
# 프레임용 json 파일 생성

# %%
import json

json_path = "/content/drive/MyDrive/Colab Notebooks/data/train_videos (1)/metadata.json"

# %%
import os
import json

base_dir = "/content/drive/MyDrive/Colab Notebooks/data/train_videos (1)/"
frame_dir = os.path.join(base_dir, "video_to_frame")

video_json_path = os.path.join(base_dir, "metadata.json")
frame_json_path = os.path.join(base_dir, "frame_metadata.json")

# 1) 영상 메타 로드
with open(video_json_path, "r", encoding="utf-8") as f:
    video_meta = json.load(f)

frame_meta = {}
matched = 0
unmatched = 0

# 2) 프레임 파일 순회
for frame_file in os.listdir(frame_dir):
    if not frame_file.lower().endswith((".png", ".jpg", ".jpeg")):
        continue

    # emfbhytfhc_0000.png -> emfbhytfhc
    video_stem = os.path.splitext(frame_file)[0].rsplit("_", 1)[0]
    video_name = video_stem + ".mp4"

    if video_name not in video_meta:
        unmatched += 1
        continue

    info = video_meta[video_name]
    frame_meta[frame_file] = {
        "label": info["label"],
        "split": info["split"],
        "video": video_name,
        "original": info["original"]
    }
    matched += 1

print("matched:", matched, "unmatched:", unmatched)

# 3) 저장
with open(frame_json_path, "w", encoding="utf-8") as f:
    json.dump(frame_meta, f, indent=2, ensure_ascii=False)

print("saved:", frame_json_path, "entries:", len(frame_meta))
# Out:
# matched: 20000 unmatched: 0
# saved: /content/drive/MyDrive/Colab Notebooks/data/train_videos (1)/frame_metadata.json entries: 20000

# %%
import json

with open("/content/drive/MyDrive/Colab Notebooks/data/train_videos (1)/frame_metadata.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print(len(data))
# Out:
# 20000

# %% [markdown]
# data sampling -> 전처리 로직 확인용

# %%
import os
import shutil
from collections import defaultdict

# 경로 설정
output_dir = os.path.join(base_dir, "selected_frames")

os.makedirs(output_dir, exist_ok=True)

# 영상별 프레임 그룹핑
video_frames = defaultdict(list)

for file in os.listdir(frame_dir):
    if not file.lower().endswith(".png"):
        continue

    # emfbhytfhc_0007.png -> emfbhytfhc
    video_name = os.path.splitext(file)[0].rsplit("_", 1)[0]
    video_frames[video_name].append(file)

# 각 영상에서 0001~0013만 복사
for video, frames in video_frames.items():
    for i in range(1, 14):  # 1 ~ 13
        target = f"{video}_{i:04d}.png"
        src_path = os.path.join(frame_dir, target)

        if not os.path.exists(src_path):
          print('frame 부족')
          continue  # 프레임 부족한 영상은 그냥 스킵

        dst_path = os.path.join(output_dir, target)
        shutil.copy(src_path, dst_path)

print("각 영상당 13개 프레임 복사 완료")
# Out:
# 각 영상당 13개 프레임 복사 완료

# %%
# 샘플 데이터에 대한 json 파일 생성

frame_json_path = os.path.join(base_dir, "frame_metadata.json")
selected_dir = os.path.join(base_dir, "selected_frames")
output_json_path = os.path.join(base_dir, "selected_frame_metadata.json")

# 1) 전체 프레임 메타 로드
with open(frame_json_path, "r", encoding="utf-8") as f:
    frame_meta = json.load(f)

# 2) selected_frames에 있는 파일 목록
selected_files = {
    f for f in os.listdir(selected_dir)
    if f.lower().endswith((".png", ".jpg", ".jpeg"))
}

print("selected files:", len(selected_files))

# 3) 선택된 프레임만 필터링
selected_meta = {}

for fname in selected_files:
    if fname in frame_meta:
        selected_meta[fname] = frame_meta[fname]

# 4) 저장
with open(output_json_path, "w", encoding="utf-8") as f:
    json.dump(selected_meta, f, indent=2, ensure_ascii=False)

print("saved:", output_json_path)
print("entries:", len(selected_meta))
# Out:
# selected files: 5200
# saved: /content/drive/MyDrive/Colab Notebooks/data/train_videos (1)/selected_frame_metadata.json
# entries: 5200

# %%
with open("/content/drive/MyDrive/Colab Notebooks/data/train_videos (1)/selected_frame_metadata.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print(len(data))
# Out:
# 5200
